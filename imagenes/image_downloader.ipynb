# %%
df_mancuernas
# Out:
#                                           title  \
# 0                 Pareja de barras de mancuerna
# 1                               Set mancuernas
# 2                  mancuernas de 6kg para casa
# 3                   2 mancuernas Reebok de 1 kg
# 4                         Pack 20 kg mancuernas
# ..                                          ...
# 275                                  Mancuerna
# 276  Set de 2 mancuernas graduables hasta 24 Kg
# 277                   KIT PESAS MANCUERNAS 20kg
# 278              Mancuerna regulable hasta 40kg
# 279         SALTER Mancuerna / Barra para pesas
#
#                                                 images
# 0    [https://cdn.wallapop.com/images/10420/eu/h6/_...
# 1    [https://cdn.wallapop.com/images/10420/eu/g2/_...
# 2    [https://cdn.wallapop.com/images/10420/eu/gm/_...
# 3    [https://cdn.wallapop.com/images/10420/eu/fh/_...
# 4    [https://cdn.wallapop.com/images/10420/eu/eq/_...
# ..                                                 ...
# 275  [https://cdn.wallapop.com/images/10420/eq/wq/_...
# 276  [https://cdn.wallapop.com/images/10420/eq/x7/_...
# 277  [https://cdn.wallapop.com/images/10420/es/9e/_...
# 278  [https://cdn.wallapop.com/images/10420/eq/4s/_...
# 279  [https://cdn.wallapop.com/images/10420/er/yb/_...
#
# [280 rows x 2 columns]

# %%
import pandas as pd

df_mancuernas = pd.read_csv('./datos/df_mancuernas.csv')
df_piano = pd.read_csv('./datos/df_piano.csv')
df_skate = pd.read_csv('./datos/df_skate.csv')

# aplica strip a la columna 'url'
df_mancuernas['images'] = df_mancuernas['images'].str.strip('[]').str.strip("'")


# aplica strip a la columna 'url'
df_piano['images'] = df_piano['images'].str.strip('[]').str.strip("'")


# aplica strip a la columna 'url'
df_skate['images'] = df_skate['images'].str.strip('[]').str.strip("'")
# Out:
#                      title                                             images
# 0             Skate board   https://cdn.wallapop.com/images/10420/eu/gx/__...
# 1              Skate Patin  https://cdn.wallapop.com/images/10420/eu/gu/__...
# 2             Monopatines   https://cdn.wallapop.com/images/10420/eu/fx/__...
# 3                   SKATE   https://cdn.wallapop.com/images/10420/eu/fr/__...
# 4            Skate Element  https://cdn.wallapop.com/images/10420/eu/gk/__...
# ..                     ...                                                ...
# 275              monopatin  https://cdn.wallapop.com/images/10420/er/lt/__...
# 276        Clases de skate  https://cdn.wallapop.com/images/10420/es/0p/__...
# 277  Patinete skate board   https://cdn.wallapop.com/images/10420/es/aj/__...
# 278  Patinete skate board   https://cdn.wallapop.com/images/10420/es/ai/__...
# 279  Patinete skate board   https://cdn.wallapop.com/images/10420/es/ai/__...
#
# [280 rows x 2 columns]

# %%
df_final += df_mancuernas
df_final += df_piano 
df_final+= df_skate
df_final = pd.DataFrame(df_final)
df_final
# Out:
#                                                  title  \
# 0    Piano Kawai CS40 ASSkate board Pareja de barra...
# 1    Piano de pared Eterna de YamahaSkate PatinSet ...
# 2    Piano de decoración Monopatines mancuernas de ...
# 3    piano yamaha clavinova clp-440 MSKATE 2 mancue...
# 4    Piano Rhodes 73Skate ElementPack 20 kg mancuer...
# ..                                                 ...
# 275  Piano de suelomonopatinMancuerna Piano de suel...
# 276  Piano Yamaha Arius YDP-v240Clases de skateSet ...
# 277  Piano RockJam 61 tecla con soporte y bancoPati...
# 278  PIANO VERTICALPatinete skate board Mancuerna r...
# 279  Piano del S. IXXPatinete skate board SALTER Ma...
#
#                                                 images
# 0    https://cdn.wallapop.com/images/10420/et/ep/__...
# 1    https://cdn.wallapop.com/images/10420/d2/j0/__...
# 2    https://cdn.wallapop.com/images/10420/eu/a0/__...
# 3    https://cdn.wallapop.com/images/10420/et/zz/__...
# 4    https://cdn.wallapop.com/images/10420/eu/az/__...
# ..                                                 ...
# 275  https://cdn.wallapop.com/images/10420/et/dr/__...
# 276  https://cdn.wallapop.com/images/10420/er/hy/__...
# 277  https://cdn.wallapop.com/images/10420/er/qa/__...
# 278  https://cdn.wallapop.com/images/10420/es/79/__...
# 279  https://cdn.wallapop.com/images/10420/et/gg/__...
#
# [280 rows x 2 columns]
